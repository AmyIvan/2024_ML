# %%
mse_all = []
mae_all = []
rmse_all = []

# %%
# 加载npy文件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


data1 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0/pred.npy')
print(data1.shape)

data2 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_0/true.npy')
print(data2.shape)


data1_min = np.min(data1)
data1_max = np.max(data1)
data1 = (data1 - data1_min) / (data1_max - data1_min)

data2_min = np.min(data2)
data2_max = np.max(data2)
data2 = (data2 - data2_min) / (data2_max - data2_min)



best_i = 0
mae = float('inf')
maelist = []
mselist = []
for i in range(data1.shape[0]):
    
    maelist.append(mean_absolute_error(data1[i], data2[i]))
    mselist.append(mean_squared_error(data1[i], data2[i]))
    tmp = maelist[-1]+np.sqrt(mselist[-1])
    if tmp < mae:
        best_i = i
        mae = tmp
print(best_i, mae)
print('mae:',sum(maelist)/len(maelist), 'mse:',sum(mselist)/len(mselist), 'rmse:',np.sqrt(sum(mselist)/len(mselist)))

mae_all.append(sum(maelist)/len(maelist))
mse_all.append(sum(mselist)/len(mselist))
rmse_all.append(np.sqrt(sum(mselist)/len(mselist)))





# 将data1和data2画在同一张图上
import matplotlib.pyplot as plt
import numpy as np
j = best_i
x1 = [i for i in range(96+96)]
x2 = [i for i in range(96, 96+96)]
data = np.concatenate((data1[j-1], data1[j]))
plt.figure(figsize=(16, 8), dpi=300)
plt.plot(x1,data, label='Ground Truth')
plt.plot(x2,data2[j], label='cnt')
plt.legend()
plt.show()
# Out:
# (3360, 96, 1)
# (3360, 96, 1)
# 143 0.103525996
# mae: 0.10656843198618542 mse: 0.022383909796259278 rmse: 0.149612532216587

# %%
# 加载npy文件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


data1 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1/pred.npy')
print(data1.shape)

data2 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1/true.npy')
print(data2.shape)


data1_min = np.min(data1)
data1_max = np.max(data1)
data1 = (data1 - data1_min) / (data1_max - data1_min)

data2_min = np.min(data2)
data2_max = np.max(data2)
data2 = (data2 - data2_min) / (data2_max - data2_min)



best_i = 0
mae = float('inf')
maelist = []
mselist = []
for i in range(data1.shape[0]):
    
    maelist.append(mean_absolute_error(data1[i], data2[i]))
    mselist.append(mean_squared_error(data1[i], data2[i]))
    tmp = maelist[-1]+np.sqrt(mselist[-1])
    if tmp < mae:
        best_i = i
        mae = tmp
print(best_i, mae)
print('mae:',sum(maelist)/len(maelist), 'mse:',sum(mselist)/len(mselist), 'rmse:',np.sqrt(sum(mselist)/len(mselist)))


mae_all.append(sum(maelist)/len(maelist))
mse_all.append(sum(mselist)/len(mselist))
rmse_all.append(np.sqrt(sum(mselist)/len(mselist)))




# 将data1和data2画在同一张图上
import matplotlib.pyplot as plt
import numpy as np
j = best_i
x1 = [i for i in range(96+96)]
x2 = [i for i in range(96, 96+96)]
data = np.concatenate((data1[j-1], data1[j]))
plt.figure(figsize=(16, 8), dpi=300)
plt.plot(x1,data, label='Ground Truth')
plt.plot(x2,data2[j], label='cnt')
plt.legend()
plt.show()
# Out:
# (3360, 96, 1)
# (3360, 96, 1)
# 527 0.10892073
# mae: 0.10568291736167988 mse: 0.02105032911883124 rmse: 0.14508731549943035

# %%
# 加载npy文件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


data1 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_2/pred.npy')
print(data1.shape)

data2 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_2/true.npy')
print(data2.shape)


data1_min = np.min(data1)
data1_max = np.max(data1)
data1 = (data1 - data1_min) / (data1_max - data1_min)

data2_min = np.min(data2)
data2_max = np.max(data2)
data2 = (data2 - data2_min) / (data2_max - data2_min)



best_i = 0
mae = float('inf')
maelist = []
mselist = []
for i in range(data1.shape[0]):
    
    maelist.append(mean_absolute_error(data1[i], data2[i]))
    mselist.append(mean_squared_error(data1[i], data2[i]))
    tmp = maelist[-1]+np.sqrt(mselist[-1])
    if tmp < mae:
        best_i = i
        mae = tmp
print(best_i, mae)
print('mae:',sum(maelist)/len(maelist), 'mse:',sum(mselist)/len(mselist), 'rmse:',np.sqrt(sum(mselist)/len(mselist)))

mae_all.append(sum(maelist)/len(maelist))
mse_all.append(sum(mselist)/len(mselist))
rmse_all.append(np.sqrt(sum(mselist)/len(mselist)))





# 将data1和data2画在同一张图上
import matplotlib.pyplot as plt
import numpy as np
j = best_i
x1 = [i for i in range(96+96)]
x2 = [i for i in range(96, 96+96)]
data = np.concatenate((data1[j-1], data1[j]))
plt.figure(figsize=(16, 8), dpi=300)
plt.plot(x1,data, label='Ground Truth')
plt.plot(x2,data2[j], label='cnt')
plt.legend()
plt.show()
# Out:
# (3360, 96, 1)
# (3360, 96, 1)
# 145 0.117308855
# mae: 0.11684974655287252 mse: 0.024102957636101305 rmse: 0.1552512725748208

# %%
# 加载npy文件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


data1 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_3/pred.npy')
print(data1.shape)

data2 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_3/true.npy')
print(data2.shape)


data1_min = np.min(data1)
data1_max = np.max(data1)
data1 = (data1 - data1_min) / (data1_max - data1_min)

data2_min = np.min(data2)
data2_max = np.max(data2)
data2 = (data2 - data2_min) / (data2_max - data2_min)



best_i = 0
mae = float('inf')
maelist = []
mselist = []
for i in range(data1.shape[0]):
    
    maelist.append(mean_absolute_error(data1[i], data2[i]))
    mselist.append(mean_squared_error(data1[i], data2[i]))
    tmp = maelist[-1]+np.sqrt(mselist[-1])
    if tmp < mae:
        best_i = i
        mae = tmp
print(best_i, mae)
print('mae:',sum(maelist)/len(maelist), 'mse:',sum(mselist)/len(mselist), 'rmse:',np.sqrt(sum(mselist)/len(mselist)))



mae_all.append(sum(maelist)/len(maelist))
mse_all.append(sum(mselist)/len(mselist))
rmse_all.append(np.sqrt(sum(mselist)/len(mselist)))


# 将data1和data2画在同一张图上
import matplotlib.pyplot as plt
import numpy as np
j = best_i
x1 = [i for i in range(96+96)]
x2 = [i for i in range(96, 96+96)]
data = np.concatenate((data1[j-1], data1[j]))
plt.figure(figsize=(16, 8), dpi=300)
plt.plot(x1,data, label='Ground Truth')
plt.plot(x2,data2[j], label='cnt')
plt.legend()
plt.show()
# Out:
# (3360, 96, 1)
# (3360, 96, 1)
# 180 0.10337511
# mae: 0.10502031564801222 mse: 0.021596249500899355 rmse: 0.14695662455602113

# %%
# 加载npy文件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


data1 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_4/pred.npy')
print(data1.shape)

data2 = np.load('/home/ymai/2024_ML/results/informer_WTH_ftMS_sl96_ll96_pl96_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_4/true.npy')
print(data2.shape)


data1_min = np.min(data1)
data1_max = np.max(data1)
data1 = (data1 - data1_min) / (data1_max - data1_min)

data2_min = np.min(data2)
data2_max = np.max(data2)
data2 = (data2 - data2_min) / (data2_max - data2_min)



best_i = 0
mae = float('inf')
maelist = []
mselist = []
for i in range(data1.shape[0]):
    
    maelist.append(mean_absolute_error(data1[i], data2[i]))
    mselist.append(mean_squared_error(data1[i], data2[i]))
    tmp = maelist[-1]+np.sqrt(mselist[-1])
    if tmp < mae:
        best_i = i
        mae = tmp
print(best_i, mae)
print('mae:',sum(maelist)/len(maelist), 'mse:',sum(mselist)/len(mselist), 'rmse:',np.sqrt(sum(mselist)/len(mselist)))



mae_all.append(sum(maelist)/len(maelist))
mse_all.append(sum(mselist)/len(mselist))
rmse_all.append(np.sqrt(sum(mselist)/len(mselist)))


# 将data1和data2画在同一张图上
import matplotlib.pyplot as plt
import numpy as np
j = best_i
x1 = [i for i in range(96+96)]
x2 = [i for i in range(96, 96+96)]
data = np.concatenate((data1[j-1], data1[j]))
plt.figure(figsize=(16, 8), dpi=300)
plt.plot(x1,data, label='Ground Truth')
plt.plot(x2,data2[j], label='cnt')
plt.legend()
plt.show()
# Out:
# (3360, 96, 1)
# (3360, 96, 1)
# 3359 0.095630035
# mae: 0.10316823364368506 mse: 0.019285511957354 rmse: 0.13887228649861713

# %%
print(mse_all)
print(mae_all)
print(rmse_all)
# Out:
# [0.022383909796259278, 0.02105032911883124, 0.024102957636101305, 0.021596249500899355, 0.019285511957354]
# [0.10656843198618542, 0.10568291736167988, 0.11684974655287252, 0.10502031564801222, 0.10316823364368506]
# [0.149612532216587, 0.14508731549943035, 0.1552512725748208, 0.14695662455602113, 0.13887228649861713]
